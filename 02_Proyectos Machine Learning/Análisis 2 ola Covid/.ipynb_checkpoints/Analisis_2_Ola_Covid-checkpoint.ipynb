# %% [markdown]
# # Análisis de la segunda ola de la COVID-19

# %% [markdown]
# ## Objetivo

# %% [markdown]
# El objetivo principal de este proyecto es poder analizar la evolución de la pandemia COVID-19 en esta segunda ola, haciendo uso de algoritmos de Machine Learning, y así poder realizar prediciones de su evolución.

# %% [markdown]
# ## Prerrequisitos

# %% [markdown]
# Para poder realizar el proyecto debemos tener instalados en nuestro sistema una serie de librerías de Data Science y Machine Learning. A continuación quedan indicadas las mismas:
#
# - Numpy
# - Pandas
# - Scikit-Learn
# - MatplotLib
# - Seaborn
#
# Todas estas librerías estan ya instaladas en el entorno de trabajo de ANACONDA 3. Solo deberemos importar las mismas.

# %% [markdown]
# ## Configuración del entorno

# %%
import warnings
warnings.filterwarnings("ignore")
import datetime
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Dataset
#
# Para analizar este problema vamos a descargarnos un dataset que pone a disposición la Unión Europea en la siguiente url:
#
# https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide

# %%
df = pd.read_excel("../Modulo 3/Dataset/COVID-19-geographic-disbtribution-worldwide-2020-11-03.xlsx")

# %% [markdown]
# Comprobamos los datos que hemos cargado en nuestro dataFrame

# %%
df.head(10)
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-11-03    3     11  2020     95       3             Afghanistan    AF
# 1 2020-11-02    2     11  2020    132       5             Afghanistan    AF
# 2 2020-11-01    1     11  2020     76       0             Afghanistan    AF
# 3 2020-10-31   31     10  2020    157       4             Afghanistan    AF
# 4 2020-10-30   30     10  2020    123       3             Afghanistan    AF
# 5 2020-10-29   29     10  2020      0       0             Afghanistan    AF
# 6 2020-10-28   28     10  2020    113       7             Afghanistan    AF
# 7 2020-10-27   27     10  2020    199       8             Afghanistan    AF
# 8 2020-10-26   26     10  2020     65       3             Afghanistan    AF
# 9 2020-10-25   25     10  2020     81       4             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
# 5                  AFG   38041757.0         Asia
# 6                  AFG   38041757.0         Asia
# 7                  AFG   38041757.0         Asia
# 8                  AFG   38041757.0         Asia
# 9                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           3.787943
# 1                                           3.766913
# 2                                           3.575019
# 3                                           3.553989
# 4                                           3.264833
# 5                                           2.941505
# 6                                           3.025623
# 7                                           2.902074
# 8                                           2.718066
# 9                                           2.799555

# %%
df.tail(10)
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 53156 2020-03-30   30      3  2020      0       0                Zimbabwe
# 53157 2020-03-29   29      3  2020      2       0                Zimbabwe
# 53158 2020-03-28   28      3  2020      2       0                Zimbabwe
# 53159 2020-03-27   27      3  2020      0       0                Zimbabwe
# 53160 2020-03-26   26      3  2020      1       0                Zimbabwe
# 53161 2020-03-25   25      3  2020      0       0                Zimbabwe
# 53162 2020-03-24   24      3  2020      0       1                Zimbabwe
# 53163 2020-03-23   23      3  2020      0       0                Zimbabwe
# 53164 2020-03-22   22      3  2020      1       0                Zimbabwe
# 53165 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 53156    ZW                  ZWE   14645473.0       Africa
# 53157    ZW                  ZWE   14645473.0       Africa
# 53158    ZW                  ZWE   14645473.0       Africa
# 53159    ZW                  ZWE   14645473.0       Africa
# 53160    ZW                  ZWE   14645473.0       Africa
# 53161    ZW                  ZWE   14645473.0       Africa
# 53162    ZW                  ZWE   14645473.0       Africa
# 53163    ZW                  ZWE   14645473.0       Africa
# 53164    ZW                  ZWE   14645473.0       Africa
# 53165    ZW                  ZWE   14645473.0       Africa
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 53156                                                NaN
# 53157                                                NaN
# 53158                                                NaN
# 53159                                                NaN
# 53160                                                NaN
# 53161                                                NaN
# 53162                                                NaN
# 53163                                                NaN
# 53164                                                NaN
# 53165                                                NaN

# %% [markdown]
# Comprobamos la info del DataFrame con el objetivo de determinar las columnas del df y el tipo de datos que contiene cada una de ellas. De esta forma, podremos realizar cualquier cambio de forma correcta según la tipología de los datos.
#
# También se comprobaran los datos estadísticos principales.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53166 entries, 0 to 53165
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     53166 non-null  datetime64[ns]
#  1   day                                                         53166 non-null  int64
#  2   month                                                       53166 non-null  int64
#  3   year                                                        53166 non-null  int64
#  4   cases                                                       53166 non-null  int64
#  5   deaths                                                      53166 non-null  int64
#  6   countriesAndTerritories                                     53166 non-null  object
#  7   geoId                                                       52932 non-null  object
#  8   countryterritoryCode                                        53084 non-null  object
#  9   popData2019                                                 53084 non-null  float64
#  10  continentExp                                                53166 non-null  object
#  11  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  50348 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 4.9+ MB

# %%
df.describe()
# Out:
#                 day         month          year          cases        deaths  \
# count  53166.000000  53166.000000  53166.000000   53166.000000  53166.000000
# mean      15.936708      6.366512   2019.998740     885.777038     22.707934
# std        8.918328      2.575420      0.035477    4977.075371    124.073255
# min        1.000000      1.000000   2019.000000   -8261.000000  -1918.000000
# 25%        8.000000      4.000000   2020.000000       0.000000      0.000000
# 50%       16.000000      6.000000   2020.000000      12.000000      0.000000
# 75%       24.000000      9.000000   2020.000000     202.000000      3.000000
# max       31.000000     12.000000   2020.000000  101273.000000   4928.000000
#
#         popData2019  \
# count  5.308400e+04
# mean   4.175643e+07
# std    1.550772e+08
# min    8.150000e+02
# 25%    1.324820e+06
# 50%    7.813207e+06
# 75%    2.860872e+07
# max    1.433784e+09
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# count                                       50348.000000
# mean                                           45.824057
# std                                           112.109316
# min                                          -147.419587
# 25%                                             0.555858
# 50%                                             5.652028
# 75%                                            39.292731
# max                                          1900.836210

# %% [markdown]
# El primer paso será cambiar el nombre de la columna 'Cumulative_number_for_days_of_COVID-19_cases_per_100000'

# %%
df = df.rename(
{'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': 'Cum14_cases_100k'}, axis = 1)
df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-11-03    3     11  2020     95       3             Afghanistan
# 1     2020-11-02    2     11  2020    132       5             Afghanistan
# 2     2020-11-01    1     11  2020     76       0             Afghanistan
# 3     2020-10-31   31     10  2020    157       4             Afghanistan
# 4     2020-10-30   30     10  2020    123       3             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 53161 2020-03-25   25      3  2020      0       0                Zimbabwe
# 53162 2020-03-24   24      3  2020      0       1                Zimbabwe
# 53163 2020-03-23   23      3  2020      0       0                Zimbabwe
# 53164 2020-03-22   22      3  2020      1       0                Zimbabwe
# 53165 2020-03-21   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  Cum14_cases_100k
# 0        AF                  AFG   38041757.0         Asia          3.787943
# 1        AF                  AFG   38041757.0         Asia          3.766913
# 2        AF                  AFG   38041757.0         Asia          3.575019
# 3        AF                  AFG   38041757.0         Asia          3.553989
# 4        AF                  AFG   38041757.0         Asia          3.264833
# ...     ...                  ...          ...          ...               ...
# 53161    ZW                  ZWE   14645473.0       Africa               NaN
# 53162    ZW                  ZWE   14645473.0       Africa               NaN
# 53163    ZW                  ZWE   14645473.0       Africa               NaN
# 53164    ZW                  ZWE   14645473.0       Africa               NaN
# 53165    ZW                  ZWE   14645473.0       Africa               NaN
#
# [53166 rows x 12 columns]

# %% [markdown]
# También se utilizará la columna dataRep como índice del DataFrame.

# %%
df.set_index('dateRep', inplace=True)

# %% [markdown]
# Y ordenamos el DataFrame por el nuevo ínidice marcado. De esta forma tendremos ordenado el df mediante la fecha de los datos.

# %%
df.sort_index(inplace=True)
df
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 2019-12-31   31     12  2019      0       0                 Nigeria    NG
# 2019-12-31   31     12  2019      0       0                 Finland    FI
# 2019-12-31   31     12  2019      0       0               Singapore    SG
# 2019-12-31   31     12  2019      0       0              Luxembourg    LU
# 2019-12-31   31     12  2019      0       0             Netherlands    NL
# ...         ...    ...   ...    ...     ...                     ...   ...
# 2020-11-03    3     11  2020      0       0             Saint_Lucia    LC
# 2020-11-03    3     11  2020     28       0                    Mali    ML
# 2020-11-03    3     11  2020      0       0                   Haiti    HT
# 2020-11-03    3     11  2020    193      13                Honduras    HN
# 2020-11-03    3     11  2020     95       3             Afghanistan    AF
#
#            countryterritoryCode  popData2019 continentExp  Cum14_cases_100k
# dateRep
# 2019-12-31                  NGA  200963603.0       Africa               NaN
# 2019-12-31                  FIN    5517919.0       Europe               NaN
# 2019-12-31                  SGP    5804343.0         Asia               NaN
# 2019-12-31                  LUX     613894.0       Europe               NaN
# 2019-12-31                  NLD   17282163.0       Europe               NaN
# ...                         ...          ...          ...               ...
# 2020-11-03                  LCA     182795.0      America         26.258924
# 2020-11-03                  MLI   19658023.0       Africa          0.844439
# 2020-11-03                  HTI   11263079.0      America          0.692528
# 2020-11-03                  HND    9746115.0      America         92.590740
# 2020-11-03                  AFG   38041757.0         Asia          3.787943
#
# [53166 rows x 11 columns]

# %% [markdown]
# ## Análisis de los datos

# %% [markdown]
# ### Qué países son los que tienen mayor incidencia de COVID con los datos disponibles?

# %% [markdown]
# Generamos un dataframe por país:

# %%
df_countries = df[['countriesAndTerritories', 'Cum14_cases_100k']].\
        groupby('countriesAndTerritories').last()
df_countries
# Out:
#                          Cum14_cases_100k
# countriesAndTerritories
# Afghanistan                      3.787943
# Albania                        145.785377
# Algeria                          9.193308
# Andorra                       1660.606220
# Angola                          10.724173
# ...                                   ...
# Wallis_and_Futuna                     NaN
# Western_Sahara                   0.000000
# Yemen                            0.010287
# Zambia                           3.616812
# Zimbabwe                         1.570451
#
# [213 rows x 1 columns]

# %% [markdown]
# Generamos un dataframe con los datos del indicador de Casos por 100.000 habitantes en los últimos 14 días

# %%
df_countries.sort_values(by=['Cum14_cases_100k'], ascending=False).\
                nlargest(25,'Cum14_cases_100k')
# Out:
#                          Cum14_cases_100k
# countriesAndTerritories
# Belgium                       1753.181152
# Andorra                       1660.606220
# Czechia                       1586.264531
# Luxembourg                    1337.853115
# French_Polynesia              1240.668135
# Slovenia                      1082.460157
# Switzerland                   1081.522710
# Armenia                        991.166192
# Liechtenstein                  990.150607
# France                         829.924001
# Netherlands                    762.410353
# Croatia                        654.695521
# Georgia                        598.384392
# Slovakia                       571.221929
# Spain                          567.244732
# Guam                           560.088466
# Poland                         558.905145
# Montenegro                     554.500130
# Austria                        537.986347
# Bosnia_and_Herzegovina         533.293265
# Italy                          510.292109
# San_Marino                     470.205788
# United_Kingdom                 469.115601
# North_Macedonia                443.351698
# Portugal                       437.760792

# %% [markdown]
# ### Analizamos la situación actual por país de la pandemia del COVID

# %%
#Generamos un nuevo dataframe con los datos agrupados
df_agrup = df.groupby('countriesAndTerritories').agg(
    # Muertes
    muertes_COVID = ('deaths', 'sum'),
    # Población total
    población = ('popData2019', 'last'),
    # Total enfermos COVID
    enfermos_COVID = ('cases', 'sum'),
    # Situación actual casos por 100k
    cum14_casos_100k_ultimo_dia = ('Cum14_cases_100k', 'last')
)
df_agrup
# Out:
#                          muertes_COVID   población  enfermos_COVID  \
# countriesAndTerritories
# Afghanistan                       1544  38041757.0           41728
# Albania                            527   2862427.0           21523
# Algeria                           1980  43053054.0           58574
# Andorra                             75     76177.0            4888
# Angola                             286  31825299.0           11035
# ...                                ...         ...             ...
# Wallis_and_Futuna                    0         NaN               1
# Western_Sahara                       1    582458.0             766
# Yemen                              600  29161922.0            2063
# Zambia                             349  17861034.0           16543
# Zimbabwe                           245  14645473.0            8389
#
#                          cum14_casos_100k_ultimo_dia
# countriesAndTerritories
# Afghanistan                                 3.787943
# Albania                                   145.785377
# Algeria                                     9.193308
# Andorra                                  1660.606220
# Angola                                     10.724173
# ...                                              ...
# Wallis_and_Futuna                                NaN
# Western_Sahara                              0.000000
# Yemen                                       0.010287
# Zambia                                      3.616812
# Zimbabwe                                    1.570451
#
# [213 rows x 4 columns]

# %% [markdown]
# Se crearan nuevas variables para poder entender mejor el impacto de la pandemia. Las nuevas variables son las siguientes:
# - Muertos por cada 100k habitantes
# - Casos por cada 100k habitantes
# - Indice mortalidad Covid

# %%
df_agrup['muertes_100k'] = df_agrup['muertes_COVID']/df_agrup['población']*100000
df_agrup['casos_100k'] = df_agrup['enfermos_COVID']/df_agrup['población']*100000
df_agrup['indice_mortalidad_COVID'] = df_agrup['muertes_COVID']/df_agrup['enfermos_COVID']*100
df_agrup
# Out:
#                          muertes_COVID   población  enfermos_COVID  \
# countriesAndTerritories
# Afghanistan                       1544  38041757.0           41728
# Albania                            527   2862427.0           21523
# Algeria                           1980  43053054.0           58574
# Andorra                             75     76177.0            4888
# Angola                             286  31825299.0           11035
# ...                                ...         ...             ...
# Wallis_and_Futuna                    0         NaN               1
# Western_Sahara                       1    582458.0             766
# Yemen                              600  29161922.0            2063
# Zambia                             349  17861034.0           16543
# Zimbabwe                           245  14645473.0            8389
#
#                          cum14_casos_100k_ultimo_dia  muertes_100k  \
# countriesAndTerritories
# Afghanistan                                 3.787943      4.058698
# Albania                                   145.785377     18.410950
# Algeria                                     9.193308      4.598977
# Andorra                                  1660.606220     98.454914
# Angola                                     10.724173      0.898656
# ...                                              ...           ...
# Wallis_and_Futuna                                NaN           NaN
# Western_Sahara                              0.000000      0.171686
# Yemen                                       0.010287      2.057478
# Zambia                                      3.616812      1.953974
# Zimbabwe                                    1.570451      1.672872
#
#                           casos_100k  indice_mortalidad_COVID
# countriesAndTerritories
# Afghanistan               109.689991                 3.700153
# Albania                   751.914372                 2.448543
# Algeria                   136.050743                 3.380339
# Andorra                  6416.634942                 1.534370
# Angola                     34.673673                 2.591754
# ...                              ...                      ...
# Wallis_and_Futuna                NaN                 0.000000
# Western_Sahara            131.511628                 0.130548
# Yemen                       7.074294                29.083858
# Zambia                     92.620618                 2.109654
# Zimbabwe                   57.280499                 2.920491
#
# [213 rows x 7 columns]

# %% [markdown]
# Ordenamos el df por el número de muertes provocadas por la COVID-19 y así vemos los paises con mas muertes y vemos también que relación tienen con el índice de mortalidad.

# %%
df_agrup =df_agrup.sort_values(by = ['muertes_COVID'], ascending=False)
df_agrup.head(20)
# Out:
#                           muertes_COVID     población  enfermos_COVID  \
# countriesAndTerritories
# United_States_of_America         231551  3.290649e+08         9291245
# Brazil                           160253  2.110495e+08         5554206
# India                            123097  1.366418e+09         8267623
# Mexico                            92100  1.275755e+08          933155
# United_Kingdom                    46853  6.664711e+07         1053864
# Italy                             39059  6.035955e+07          731588
# France                            37435  6.701288e+07         1466433
# Spain                             36257  4.693706e+07         1240697
# Iran                              35738  8.291389e+07          628780
# Peru                              34585  3.251046e+07          906545
# Colombia                          31670  5.033944e+07         1093256
# Argentina                         31623  4.478068e+07         1183118
# Russia                            28473  1.458723e+08         1655038
# South_Africa                      19465  5.855827e+07          727595
# Chile                             14302  1.895204e+07          513188
# Indonesia                         14044  2.706256e+08          415402
# Ecuador                           12692  1.737366e+07          169562
# Belgium                           11858  1.145552e+07          447260
# Iraq                              11017  3.930979e+07          478701
# Germany                           10661  8.301921e+07          560379
#
#                           cum14_casos_100k_ultimo_dia  muertes_100k  \
# countriesAndTerritories
# United_States_of_America                   327.136059     70.366359
# Brazil                                     143.795163     75.931469
# India                                       49.074304      9.008738
# Mexico                                      61.319754     72.192528
# United_Kingdom                             469.115601     70.300120
# Italy                                      510.292109     64.710560
# France                                     829.924001     55.862393
# Spain                                      567.244732     77.245997
# Iran                                       113.550331     43.102547
# Peru                                       109.715451    106.381140
# Colombia                                   253.028227     62.912893
# Argentina                                  403.006431     70.617515
# Russia                                     164.336934     19.519133
# South_Africa                                38.151744     33.240396
# Chile                                      104.912217     75.464192
# Indonesia                                   18.535573      5.189458
# Ecuador                                     92.893511     73.053129
# Belgium                                   1753.181152    103.513424
# Iraq                                       122.165499     28.026098
# Germany                                    225.504426     12.841606
#
#                            casos_100k  indice_mortalidad_COVID
# countriesAndTerritories
# United_States_of_America  2823.529498                 2.492142
# Brazil                    2631.707490                 2.885255
# India                      605.058223                 1.488904
# Mexico                     731.452973                 9.869743
# United_Kingdom            1581.259815                 4.445830
# Italy                     1212.050203                 5.338934
# France                    2188.285199                 2.552793
# Spain                     2643.320651                 2.922309
# Iran                       758.353006                 5.683705
# Peru                      2788.471600                 3.815034
# Colombia                  2171.768170                 2.896851
# Argentina                 2642.028062                 2.672853
# Russia                    1134.580351                 1.720383
# South_Africa              1242.514571                 2.675252
# Chile                     2707.825307                 2.786893
# Indonesia                  153.496953                 3.380821
# Ecuador                    975.971841                 7.485168
# Belgium                   3904.318958                 2.651254
# Iraq                      1217.765376                 2.301437
# Germany                    674.999172                 1.902462

# %% [markdown]
# **Al realizar la última comprobación se ha detectado que algunos paises tienen un índice de mortalidad muy alto. Este hecho puede venir dado porque, estos mismos paises no contabilizan todos los enfermos de COVID, peró si las muertes, ya que estas es mas difícil esconderlas y/o obviarlas!!!**
#
# **Esto puede distorsionar los datos**

# %% [markdown]
# Vamos a realizar un histograma para ver la distribución de índices de mortalidad.

# %%
df_agrup['indice_mortalidad_COVID'].plot(kind= 'hist', title= 'Distribución países por índice de mortalidad')
plt.show()

# %% [markdown]
# Del histograma podemos sacar la conclusión de que la mayor parte de países tienen un índice de mortalidad que se encuentra entre el 0 y el 2,5%.
#
# Por otra parte, podemos observar que existen algunos casos cuyo índice de kortalidad está en torno al 28%. Se trata de un índice muy superior a la media de los países afectados por la pandemia. Esto indica que los datos dispuestos de este país no son fiables o faltan parte de ellos.

# %% [markdown]
# ## Modelos

# %% [markdown]
# ### Diferenciar grupos de países aplicando un algoritmo de clustering a los datos

# %% [markdown]
# Creamos un nuevo dataframe con las variables mas representativas de que disponemos en nuestro dataset

# %%
variables_clustering = ['cum14_casos_100k_ultimo_dia', 
                        'casos_100k', 
                        'muertes_100k', 
                        'indice_mortalidad_COVID']
df_clustering = df_agrup[variables_clustering]
df_clustering.head(20)
# Out:
#                           cum14_casos_100k_ultimo_dia   casos_100k  \
# countriesAndTerritories
# United_States_of_America                   327.136059  2823.529498
# Brazil                                     143.795163  2631.707490
# India                                       49.074304   605.058223
# Mexico                                      61.319754   731.452973
# United_Kingdom                             469.115601  1581.259815
# Italy                                      510.292109  1212.050203
# France                                     829.924001  2188.285199
# Spain                                      567.244732  2643.320651
# Iran                                       113.550331   758.353006
# Peru                                       109.715451  2788.471600
# Colombia                                   253.028227  2171.768170
# Argentina                                  403.006431  2642.028062
# Russia                                     164.336934  1134.580351
# South_Africa                                38.151744  1242.514571
# Chile                                      104.912217  2707.825307
# Indonesia                                   18.535573   153.496953
# Ecuador                                     92.893511   975.971841
# Belgium                                   1753.181152  3904.318958
# Iraq                                       122.165499  1217.765376
# Germany                                    225.504426   674.999172
#
#                           muertes_100k  indice_mortalidad_COVID
# countriesAndTerritories
# United_States_of_America     70.366359                 2.492142
# Brazil                       75.931469                 2.885255
# India                         9.008738                 1.488904
# Mexico                       72.192528                 9.869743
# United_Kingdom               70.300120                 4.445830
# Italy                        64.710560                 5.338934
# France                       55.862393                 2.552793
# Spain                        77.245997                 2.922309
# Iran                         43.102547                 5.683705
# Peru                        106.381140                 3.815034
# Colombia                     62.912893                 2.896851
# Argentina                    70.617515                 2.672853
# Russia                       19.519133                 1.720383
# South_Africa                 33.240396                 2.675252
# Chile                        75.464192                 2.786893
# Indonesia                     5.189458                 3.380821
# Ecuador                      73.053129                 7.485168
# Belgium                     103.513424                 2.651254
# Iraq                         28.026098                 2.301437
# Germany                      12.841606                 1.902462

# %%
df_clustering = df_clustering.sort_values(by = ['cum14_casos_100k_ultimo_dia'], ascending=False)
df_clustering.head(20)
# Out:
#                          cum14_casos_100k_ultimo_dia   casos_100k  \
# countriesAndTerritories
# Belgium                                  1753.181152  3904.318958
# Andorra                                  1660.606220  6416.634942
# Czechia                                  1586.264531  3294.859997
# Luxembourg                               1337.853115  3111.449208
# French_Polynesia                         1240.668135  2600.211254
# Slovenia                                 1082.460157  1739.913538
# Switzerland                              1081.522710  2054.765583
# Armenia                                   991.166192  3204.351448
# Liechtenstein                             990.150607  1581.635312
# France                                    829.924001  2188.285199
# Netherlands                               762.410353  2127.713990
# Croatia                                   654.695521  1291.874926
# Georgia                                   598.384392  1065.337391
# Slovakia                                  571.221929  1134.389435
# Spain                                     567.244732  2643.320651
# Guam                                      560.088466  2805.224304
# Poland                                    558.905145  1041.481995
# Montenegro                                554.500130  3087.521015
# Austria                                   537.986347  1289.907465
# Bosnia_and_Herzegovina                    533.293265  1583.430223
#
#                          muertes_100k  indice_mortalidad_COVID
# countriesAndTerritories
# Belgium                    103.513424                 2.651254
# Andorra                     98.454914                 1.534370
# Czechia                     34.310503                 1.041334
# Luxembourg                  26.063131                 0.837652
# French_Polynesia            10.383658                 0.399339
# Slovenia                    12.062042                 0.693255
# Switzerland                 24.904831                 1.212052
# Armenia                     47.773156                 1.490884
# Liechtenstein                7.816978                 0.494234
# France                      55.862393                 2.552793
# Netherlands                 43.125389                 2.026841
# Croatia                     14.572231                 1.127991
# Georgia                      8.556927                 0.803213
# Slovakia                     4.018038                 0.354203
# Spain                       77.245997                 2.922309
# Guam                        47.221973                 1.683358
# Poland                      15.471596                 1.485537
# Montenegro                  51.431896                 1.665799
# Austria                     12.812155                 0.993262
# Bosnia_and_Herzegovina      38.776152                 2.448870

# %% [markdown]
# #### Calculamos la correlación entre las variables

# %%
df_clustering.corr()
# Out:
#                              cum14_casos_100k_ultimo_dia  casos_100k  \
# cum14_casos_100k_ultimo_dia                     1.000000    0.670030
# casos_100k                                      0.670030    1.000000
# muertes_100k                                    0.501746    0.684265
# indice_mortalidad_COVID                        -0.086904   -0.094868
#
#                              muertes_100k  indice_mortalidad_COVID
# cum14_casos_100k_ultimo_dia      0.501746                -0.086904
# casos_100k                       0.684265                -0.094868
# muertes_100k                     1.000000                 0.233777
# indice_mortalidad_COVID          0.233777                 1.000000

# %% [markdown]
# De la tabla de correlaciones podemos obtener varias conclusiones:
# - En el caso de los países que han tenido casos por cada 100k habitantes tienen un índice de correlación alto (68,4%) con los casos en los últimos 14 días.
# - En cambio la relación con las muertes es baja (51,5%)
# - No se ve una correlación fuerte entre las variables

# %% [markdown]
# ### Para llevar a cabo la clusterización haremos uso del algoritmo de clasificación K-Means

# %%
#Importamos K-means
from sklearn.cluster import KMeans

# %% [markdown]
# **Se procede a preparar los datos para poder llevar a cabo la aplicación del algoritmo**

# %% [markdown]
# Primero se comprobará que no haya datos nulos

# %%
df_clustering.isnull().sum().sort_values(ascending=False)
# Out:
# cum14_casos_100k_ultimo_dia    3
# muertes_100k                   2
# casos_100k                     2
# indice_mortalidad_COVID        0
# dtype: int64

# %% [markdown]
# Borramos los datos nulos para evitar interferencias con los análisis

# %%
df_clustering = df_clustering.dropna()

# %% [markdown]
# Normalizamos los datospara que las diferentes unidades de medida que tienen nuestras variables esten a la misma escala y no interfieran con el modelo

# %%
from sklearn.preprocessing import StandardScaler, normalize
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df_clustering)

normalized_df = normalize(scaled_df)

# %%
# Convertimos la matriz normalizada en un DataFrame
normalized_df = pd.DataFrame(normalized_df, columns = df_clustering.columns)

# %%
normalized_df.head(10)
# Out:
#    cum14_casos_100k_ultimo_dia  casos_100k  muertes_100k  \
# 0                     0.747726    0.392394      0.534849
# 1                     0.626086    0.637425      0.448146
# 2                     0.892077    0.418168      0.150817
# 3                     0.875089    0.459521      0.099628
# 4                     0.899371    0.397668     -0.058030
# 5                     0.951060    0.248380     -0.049426
# 6                     0.929538    0.330602      0.120212
# 7                     0.732721    0.568761      0.367590
# 8                     0.941736    0.223898     -0.117113
# 9                     0.723073    0.394258      0.564504
#
#    indice_mortalidad_COVID
# 0                 0.029490
# 1                -0.029527
# 2                -0.081171
# 3                -0.114604
# 4                -0.172116
# 5                -0.177059
# 6                -0.110500
# 7                -0.067145
# 8                -0.222008
# 9                 0.055333

# %% [markdown]
# ### Modelo K-means

# %% [markdown]
# A la hora de llevar a cabo el modelo de clusterización mediante el algoritmo K-means deberemos prestar atención a los siguientes parámetros:
# - Determinar correctamente el valor k (número de clusters).
# - Inicializar correctamente los clusters
#
# Para determinar el número de clústers correcto se procede a utilizar el método del codo. Este método lo que hace es calcular Kmeans para distintos valores de k y quedarse con el que el error sea mínimo. En este caso utilizaremos de error la variable 'inertia'que mediará el desajuste entre los datos y los clusters.

# %%
desajuste = []
for i in range (1, 16):
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(normalized_df)
    desajuste.append(km.inertia_)
    
plt.figure(figsize =(6, 3))
plt.plot(range(1, 16), desajuste, marker='o')
plt.xlabel('k')
plt.ylabel('desajuste')
plt.show()

# %% [markdown]
# Podemos determinar que el mejor número de clusters es de 4 a 6. Si agregamos mas clusters no obtendremos ninguna ganancia

# %%
n_clusters = 4
km = KMeans(n_clusters=n_clusters)
km.fit(normalized_df)
# Out:
# KMeans(n_clusters=4)

# %%
# Agregamos la etiqueta de cada uno de los clusters al dataframe
df_clustering['Cluster'] = km.predict(normalized_df)
df_clustering.head(10)
# Out:
#                          cum14_casos_100k_ultimo_dia   casos_100k  \
# countriesAndTerritories
# Belgium                                  1753.181152  3904.318958
# Andorra                                  1660.606220  6416.634942
# Czechia                                  1586.264531  3294.859997
# Luxembourg                               1337.853115  3111.449208
# French_Polynesia                         1240.668135  2600.211254
# Slovenia                                 1082.460157  1739.913538
# Switzerland                              1081.522710  2054.765583
# Armenia                                   991.166192  3204.351448
# Liechtenstein                             990.150607  1581.635312
# France                                    829.924001  2188.285199
#
#                          muertes_100k  indice_mortalidad_COVID  Cluster
# countriesAndTerritories
# Belgium                    103.513424                 2.651254        1
# Andorra                     98.454914                 1.534370        1
# Czechia                     34.310503                 1.041334        3
# Luxembourg                  26.063131                 0.837652        3
# French_Polynesia            10.383658                 0.399339        3
# Slovenia                    12.062042                 0.693255        3
# Switzerland                 24.904831                 1.212052        3
# Armenia                     47.773156                 1.490884        3
# Liechtenstein                7.816978                 0.494234        3
# France                      55.862393                 2.552793        1

# %%
# Cálculo promedio de cada uno de los clusters
df_clustering.groupby('Cluster').mean()
# Out:
#          cum14_casos_100k_ultimo_dia   casos_100k  muertes_100k  \
# Cluster
# 0                          18.390733   224.190826      8.525944
# 1                         326.885842  2125.823387     50.884495
# 2                          24.277771   216.766154      2.617328
# 3                         483.378152  1653.094930     13.593248
#
#          indice_mortalidad_COVID
# Cluster
# 0                       4.933403
# 1                       2.849107
# 2                       1.208944
# 3                       0.984061

# %%
# Se crea un Headmap para visualizar los datos de los clusters

cm = sns.light_palette('red', as_cmap=True)
df_clustering.groupby('Cluster').mean().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row0_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row0_col2 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row0_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row1_col0 {
#             background-color:  #e43027;
#             color:  #f1f1f1;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row1_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row1_col3 {
#             background-color:  #fb7353;
#             color:  #000000;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row2_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row2_col3 {
#             background-color:  #ffece3;
#             color:  #000000;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row3_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row3_col1 {
#             background-color:  #ca181d;
#             color:  #f1f1f1;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row3_col2 {
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }    #T_a82a10f0_21e8_11eb_8f52_d0c637873c54row3_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cum14_casos_100k_ultimo_dia</th>        <th class="col_heading level0 col1" >casos_100k</th>        <th class="col_heading level0 col2" >muertes_100k</th>        <th class="col_heading level0 col3" >indice_mortalidad_COVID</th>    </tr>    <tr>        <th class="index_name level0" >Cluster</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row0_col0" class="data row0 col0" >18.390733</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row0_col1" class="data row0 col1" >224.190826</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row0_col2" class="data row0 col2" >8.525944</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row0_col3" class="data row0 col3" >4.933403</td>
#             </tr>
#             <tr>
#                         <th id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row1_col0" class="data row1 col0" >326.885842</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row1_col1" class="data row1 col1" >2125.823387</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row1_col2" class="data row1 col2" >50.884495</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row1_col3" class="data row1 col3" >2.849107</td>
#             </tr>
#             <tr>
#                         <th id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row2_col0" class="data row2 col0" >24.277771</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row2_col1" class="data row2 col1" >216.766154</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row2_col2" class="data row2 col2" >2.617328</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row2_col3" class="data row2 col3" >1.208944</td>
#             </tr>
#             <tr>
#                         <th id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row3_col0" class="data row3 col0" >483.378152</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row3_col1" class="data row3 col1" >1653.094930</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row3_col2" class="data row3 col2" >13.593248</td>
#                         <td id="T_a82a10f0_21e8_11eb_8f52_d0c637873c54row3_col3" class="data row3 col3" >0.984061</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Con el Headmap podemos observar las diferencias presentes entre cada uno de los clusters:
#
# 1- Cluster 0 = un índice de mortalidad muy elevado sin haber tenido gran cantidad de casos de Covid. Los países pertenecientes a este clúster es posible que hay una falta de datos de recuento de positivos en COVID.
#
# 2- Cluster 1 = gran incidencia de casos, tanto totales como en los últimos 14 días, con un índice de mortalidad medio.
#
# 3- Cluster 2 = baja incidencia de Covid, con índices bajos de contagios y baja mortalidad. Existe una fuerte correlación.
#
# 4- Cluster 3 = gran cantidad de casos, con índices de mortalidad bajos.

# %% [markdown]
# ### Veamos la clasificación para algunos países

# %%
df_clustering.loc['Spain']
# Out:
# cum14_casos_100k_ultimo_dia     567.244732
# casos_100k                     2643.320651
# muertes_100k                     77.245997
# indice_mortalidad_COVID           2.922309
# Cluster                           1.000000
# Name: Spain, dtype: float64

# %%
df_clustering.loc['France']
# Out:
# cum14_casos_100k_ultimo_dia     829.924001
# casos_100k                     2188.285199
# muertes_100k                     55.862393
# indice_mortalidad_COVID           2.552793
# Cluster                           1.000000
# Name: France, dtype: float64

# %%
df_clustering.loc['Japan']
# Out:
# cum14_casos_100k_ultimo_dia     6.937553
# casos_100k                     80.624909
# muertes_100k                    1.403118
# indice_mortalidad_COVID         1.740304
# Cluster                         2.000000
# Name: Japan, dtype: float64

# %%
df_clustering.loc['Belgium']
# Out:
# cum14_casos_100k_ultimo_dia    1753.181152
# casos_100k                     3904.318958
# muertes_100k                    103.513424
# indice_mortalidad_COVID           2.651254
# Cluster                           1.000000
# Name: Belgium, dtype: float64

# %% [markdown]
# ## Análisis en detalle de los 25 países con mayor número de contagio

# %%
top25country = df[['countriesAndTerritories', 'cases']].\
                    groupby('countriesAndTerritories').sum().\
                    sort_values('cases', ascending=False).\
                    nlargest(25, 'cases')
top25country
# Out:
#                             cases
# countriesAndTerritories
# United_States_of_America  9291245
# India                     8267623
# Brazil                    5554206
# Russia                    1655038
# France                    1466433
# Spain                     1240697
# Argentina                 1183118
# Colombia                  1093256
# United_Kingdom            1053864
# Mexico                     933155
# Peru                       906545
# Italy                      731588
# South_Africa               727595
# Iran                       628780
# Germany                    560379
# Chile                      513188
# Iraq                       478701
# Belgium                    447260
# Indonesia                  415402
# Bangladesh                 410988
# Ukraine                    402194
# Poland                     395480
# Philippines                385400
# Turkey                     379775
# Netherlands                367715

# %% [markdown]
# Se realizará una matriz de gráficos para ver la evolución de la tasa de casos de los últimos 14 días por 100k habitantes.

# %%
fig, axes = plt.subplots(nrows=5, ncols=5, sharex=True, sharey=True, figsize= (15,15))
axes_list = [item for sublist in axes for item in sublist]

for countryname in top25country.index.values:
    ax = axes_list.pop(0)
    selection=df[df['countriesAndTerritories']==countryname]['Cum14_cases_100k']
    selection.plot( y='Cum14_cases_100k', label=countryname, ax=ax, legend=False)
    ax.set_title(countryname)
    ax.tick_params(
        which='both',
        bottom='off',
        left='off',
        right='off',
        top='off'
    )
    ax.grid(linewidth=0.20)
    ax.set_ylim((0, 900))
    ax.spines['left'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    
#borramos todo lo que no usamos en el plot

for ax in axes_list:
    ax.remove()

# %% [markdown]
# En esta matriz de plots se puede observar la evolución de la pandemia desde principios de año hasta principios de noviembre. Se podrían analizar las diferentes políticas aplicadas en cada uno de los países y su efecto en los datos acumulados.

# %% [markdown]
# ### Realizamos el estudio de la evolución de los casos en España

# %%
df[df['countriesAndTerritories']=='Spain']['cases'].plot()

# %% [markdown]
# Los picos que se observan vienen dada porque en fin de semana no se dan datos y a principios de semana se observa el crecimieto exponencial de los datos acumulados de fin de semana.

# %%
# Ahora miramos la evolución de las muertes en España
df[df['countriesAndTerritories']=='Spain']['deaths'].plot()

# %% [markdown]
# En este segundo plot de la evolución de muertes se pueden observar dos picos; uno de ellos positivo y otro negativo. Esto hace referencia a recuentos de muertes por Covid no contabilizadas en su momento de hecho.

# %%
df[df['countriesAndTerritories']=='Spain']['deaths'].rolling(window=7).mean().plot()

# %% [markdown]
# ### Como ha evolucionado el índice de mortalidad en España

# %%
#Se crea un dataframe donde queden representados los fallecimientos y los contagios.

df_fallecimientos = df[df['countriesAndTerritories'] == 'Spain'][['deaths','cases']]

# %%
df_fallecimientos.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002BCD612D910>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002BCD618FC70>],
#       dtype=object)

# %% [markdown]
# Debido a que España es un país que no ha comunicado los datos de muertes y casos de forma diaria, ya que durante el fin de semana no ha comunicado ningún caso o fallecimiento, calculamos la media móvil para interpretar mejor los gráficos.

# %%
df_fallecimientos['deaths_mm7'] = df_fallecimientos['deaths'].rolling(window=7).mean()

# %%
df_fallecimientos['cases_mm7'] = df_fallecimientos['cases'].rolling(window=7).mean()

# %%
df_fallecimientos[['cases_mm7','cases']].plot()

# %%
df_fallecimientos[['deaths_mm7','deaths']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002BCDBA31B50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002BCDBA77880>],
#       dtype=object)

# %%
df_fallecimientos['indice_mortalidad'] = df_fallecimientos['deaths_mm7']/df_fallecimientos['cases_mm7']*100

# %%
df_fallecimientos['indice_mortalidad'].plot()

# %% [markdown]
# Esta diferencia en la gráfica es debida a que los datos estadísticos de la pandemia no se han tratado de la forma correcta. Otro factor que influye en los datos es la evolución de los protocolos seguidos para la detección de casos, ya que han ido variando a lo largo del tiempo.

# %% [markdown]
# **Se procede a dividir los datos en las dos oleadas de la pandemia, y así eliminar la parte donde España realizó el ajuste en las muertes**

# %%
df_fallecimientos.loc[:'2020-05-15']['indice_mortalidad'].plot()

# %%
df_fallecimientos['indice_mortalidad'].iloc[190:].plot()

# %% [markdown]
# En este último gráfico podemos observar la evolución del índice de mortalidad durante la segunda ola de la pandemia. Se puede observar que un índice de mortalidad acorde a la realidad, ya que no existen ajustes en los datos, como si ocurre durante la primera ola, donde no se apuntaban todos los casos reales, ya que no se hacían pruebas PCR.

# %%
df_fallecimientos['indice_mortalidad_2'] = df_fallecimientos['deaths_mm7']\
                                        /df_fallecimientos['cases_mm7'].shift(14)*100

# %%
df_fallecimientos.loc['2020-04-1':'2020-05-15']['indice_mortalidad_2'].plot()

# %% [markdown]
# Aquí podemos observar, como después de los ajustes en los datos de casos y muertos, el índice de mortalidad se va ajustando a dats reales. También coincidió con el cambio en los protocolos de detección de casos mediantes las pruebas PCR.

# %%
df_fallecimientos['indice_mortalidad'].loc['2020-08-1':].plot();

# %% [markdown]
# En este último gráfico se observa la evolución del índice de mortalidad a lo largo de la segunda ola. Se puede determinar que el índice real se mueve entre el 0,2% y un 1% (dato muy elevado para una pandemia de esta tipología.

# %% [markdown]
# ## Modelo de predicción

# %% [markdown]
# **Se utilizará un modelo de regresión SVR con el objetivo de determinar la predicción de la evolución futura de la pandemia con los datos que tenemos hasta hoy. Y como variable utilizamos el número de días que han transcurrido desde el inicio de la pandemia en España.**

# %%
# Se utiliza la variable de media movil semanal de casos.
data = pd.DataFrame(df_fallecimientos['cases_mm7'])

# %%
#El inicio de la pandemia lo indica cuando llegamos al caso 100
fecha100 = data[data.cases_mm7.cumsum()<100].index.max()
fecha100
# Out:
# Timestamp('2020-03-03 00:00:00')

# %%
data = data[fecha100:]
data
# Out:
#                cases_mm7  n-dia
# dateRep
# 2020-03-03     27.000000     63
# 2020-03-04     36.857143     64
# 2020-03-05     47.285714     65
# 2020-03-06     70.857143     66
# 2020-03-07    101.428571     67
# ...                  ...    ...
# 2020-10-29  19114.571429    303
# 2020-10-30  19935.142857    304
# 2020-10-31  19935.142857    305
# 2020-11-01  19935.142857    306
# 2020-11-02  20339.571429    307
#
# [245 rows x 2 columns]

# %%
data['n-dia']=0
for i in range(data.shape[0]):
    data['n-dia'][i]=i

data
# Out:
#                cases_mm7  n-dia
# dateRep
# 2020-03-03     27.000000      0
# 2020-03-04     36.857143      1
# 2020-03-05     47.285714      2
# 2020-03-06     70.857143      3
# 2020-03-07    101.428571      4
# ...                  ...    ...
# 2020-10-29  19114.571429    240
# 2020-10-30  19935.142857    241
# 2020-10-31  19935.142857    242
# 2020-11-01  19935.142857    243
# 2020-11-02  20339.571429    244
#
# [245 rows x 2 columns]

# %% [markdown]
# Observando los datos, desarrollamos el modelo solo a partir del 1 de mayo como fecha inicio

# %%
data = data.loc['2020-05-1':]

data
# Out:
#                cases_mm7  n-dia
# dateRep
# 2020-05-01   1543.857143     59
# 2020-05-02   1362.142857     60
# 2020-05-03   1261.285714     61
# 2020-05-04   1090.714286     62
# 2020-05-05   1021.285714     63
# ...                  ...    ...
# 2020-10-29  19114.571429    240
# 2020-10-30  19935.142857    241
# 2020-10-31  19935.142857    242
# 2020-11-01  19935.142857    243
# 2020-11-02  20339.571429    244
#
# [186 rows x 2 columns]

# %%
x = data['n-dia'].values

x
# Out:
# array([ 59,  60,  61,  62,  63,  64,  65,  66,  67,  68,  69,  70,  71,
#         72,  73,  74,  75,  76,  77,  78,  79,  80,  81,  82,  83,  84,
#         85,  86,  87,  88,  89,  90,  91,  92,  93,  94,  95,  96,  97,
#         98,  99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
#        111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123,
#        124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136,
#        137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149,
#        150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162,
#        163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175,
#        176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188,
#        189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201,
#        202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214,
#        215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227,
#        228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240,
#        241, 242, 243, 244], dtype=int64)

# %%
y = data['cases_mm7'].values

y
# Out:
# array([ 1543.85714286,  1362.14285714,  1261.28571429,  1090.71428571,
#         1021.28571429,  1026.        ,   980.28571429,   949.71428571,
#          879.57142857,  1234.        ,  1223.57142857,  1144.        ,
#         1081.        ,  1070.71428571,   995.        ,   962.42857143,
#          567.57142857,   548.        ,   540.71428571,   552.        ,
#          499.57142857,   663.        ,   656.        ,   631.71428571,
#          542.        ,   603.14285714,   602.        ,   695.57142857,
#          534.28571429,   562.57142857,   522.42857143,   605.42857143,
#          524.71428571,   508.14285714,   393.42857143,   344.85714286,
#          297.42857143,   303.        ,   297.        ,   290.57142857,
#          279.14285714,   292.42857143,   318.71428571,   327.85714286,
#          339.71428571,   341.71428571,   337.42857143,   343.28571429,
#          365.85714286,   338.        ,   333.28571429,   334.85714286,
#          342.14285714,   346.28571429,   343.28571429,   316.85714286,
#          332.85714286,   361.57142857,   356.85714286,   352.28571429,
#          359.85714286,   367.57142857,   373.85714286,   377.14285714,
#          296.57142857,   253.57142857,   402.71428571,   408.42857143,
#          407.71428571,   421.85714286,   480.42857143,   480.42857143,
#          480.42857143,   594.85714286,   641.28571429,   711.57142857,
#          828.42857143,   906.71428571,   906.71428571,   906.71428571,
#         1269.        ,  1367.85714286,  1436.71428571,  1615.85714286,
#         1738.        ,  1738.        ,  1738.        ,  1992.28571429,
#         2059.42857143,  2155.71428571,  2180.57142857,  2300.14285714,
#         2300.14285714,  2300.14285714,  2610.28571429,  3172.        ,
#         3303.71428571,  3489.28571429,  3691.42857143,  3691.42857143,
#         3691.42857143,  3703.71428571,  3399.71428571,  3431.        ,
#         3925.57142857,  4064.42857143,  4064.42857143,  4064.42857143,
#         5157.42857143,  5369.14285714,  5869.        ,  5796.        ,
#         6177.28571429,  6177.28571429,  6177.28571429,  6622.        ,
#         6908.14285714,  6997.42857143,  7371.57142857,  7604.57142857,
#         7604.57142857,  7604.57142857,  8203.14285714,  8345.71428571,
#         8529.28571429,  8429.42857143,  8529.        ,  8529.        ,
#         8529.        ,  8955.85714286,  9077.14285714,  9117.85714286,
#         9375.71428571,  9619.57142857,  9619.57142857,  9619.57142857,
#         9740.14285714,  9807.71428571, 10140.14285714, 10215.42857143,
#        10530.57142857, 10530.57142857, 10530.57142857, 11105.42857143,
#        11300.        , 11313.71428571, 11222.57142857, 10920.14285714,
#        10920.14285714, 10920.14285714, 10971.14285714, 10843.57142857,
#        10804.57142857, 10628.28571429, 10493.        , 10493.        ,
#        10493.        ,  9306.57142857,  9605.42857143,  9530.42857143,
#         9959.57142857, 10168.57142857, 10168.57142857, 10168.57142857,
#        10793.71428571, 10096.57142857, 10307.85714286, 10435.71428571,
#        10778.28571429, 10778.28571429, 10778.28571429, 12211.57142857,
#        13176.57142857, 13891.28571429, 14986.71428571, 15653.14285714,
#        15653.14285714, 15653.14285714, 17695.85714286, 18345.14285714,
#        18744.        , 19114.57142857, 19935.14285714, 19935.14285714,
#        19935.14285714, 20339.57142857])

# %%
#Normalizo los datos de la variable

x = x.reshape(-1,1)
y = y.reshape(-1,1)

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()

x = sc_x.fit_transform(x)
y = sc_y.fit_transform(y)

# %%
from sklearn.svm import SVR

regressor = SVR(kernel = 'rbf', C= 100, gamma= .1, epsilon= .1)
regressor.fit(x, y)
# Out:
# SVR(C=100, gamma=0.1)

# %%
x_grid = np.arange(min(x), max(x)*5, 0.1)
x_grid = x_grid.reshape((len(x_grid),1))
prediccion = regressor.predict(x_grid)
prediccion_t = np.rint(sc_y.inverse_transform(prediccion))
x_t = sc_x.inverse_transform(x)
y_t = sc_y.inverse_transform(y)
plt.scatter(x_t, y_t, color= 'red')
x_grid_t = sc_x.inverse_transform(x_grid)
plt.plot(x_grid_t, prediccion_t, color='green')
plt.title('Evolución casos Covid-19 España')
plt.ylabel('Número de casos')
plt.xlabel('Días desde inicio de la pandemia')
plt.show()

# %% [markdown]
# Para ajustar mejor el modelo, cogemos los datos solo de la segunda ola de la pandemia y así observamos la previsión de evolución.

# %% [markdown]
# **Previsión máximo pandemia**

# %%
maximo = np.max(prediccion_t)
maximo
# Out:
# 31951.0

# %%
# El dia que alcanzaremos el máximo?

dias_maximo = np.rint(x_grid_t[np.where(prediccion_t == maximo)][0,0])
dias_maximo
# Out:
# 419.0

# %%
fecha100 + datetime.timedelta(days=dias_maximo)
# Out:
# Timestamp('2021-04-26 00:00:00')

# %% [markdown]
# Con los datos extraidos del modelo de predicción podemos indicar que el máximo de casos se daran el próximo día 26 de abril de 2021 alcanzando los 31951 casos.
#
# **Se debe tener en cuenta que se trata de una predicción y conociendo que los datos estadísticos de la primera ola fueron incorrectos debido a la falta de ellos o recuentos tardíos**
